# %%
# Import necessary classes from the scripts
from scripts.time_series_analysis import TimeSeriesAnalyzer, plot_stock_data, plot_time_series
from scripts.utils import StockDataLoader
# Import pandas and matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load the news data
file_path = "../src/data/stock_news_data/raw_analyst_ratings.csv"
news_data = pd.read_csv(file_path, parse_dates=["date"])

# %%
# Initialize the TimeSeriesAnalyzer class and perform time series analysis
time_series_analyzer = TimeSeriesAnalyzer(news_data)

# %%
# Analyze publication frequency and plot the results
publication_frequency = time_series_analyzer.analyze_publication_frequency()
plot_time_series(publication_frequency, "Publication Frequency Over Time", "Date", "Number of Articles")
# Out:
# /home/besu/PycharmProjects/financial_news_stock_price_analysis/scripts/time_series_analysis.py:60: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   self.news_data['date'] = pd.to_datetime(self.news_data['date'], errors='coerce', infer_datetime_format=True)

# %%
# Analyze publishing times and plot the results
publishing_times = time_series_analyzer.analyze_publishing_times()
publishing_times.plot(kind='bar', figsize=(10, 6))
plt.title("Publishing Times Distribution")
plt.xlabel("Hour")
plt.ylabel("Number of Articles")
plt.show()

# %%
# Load and plot stock data for all tickers
stock_loader = StockDataLoader()
stock_data_dict = stock_loader.load_all_stock_data()

# %%
# Plot stock data for each ticker
for ticker, stock_data in stock_data_dict.items():
    plot_stock_data(stock_data, ticker)
